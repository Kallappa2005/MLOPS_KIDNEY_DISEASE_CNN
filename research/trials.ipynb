# %%
# about what are the configbox and the ensureannotations

# %%
fuels = {"discipline":"pos","consistency":"pos2"}

# %%
fuels["discipline"]
# Out:
# 'pos'

# %%
fuels.discipline
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 fuels.discipline
#
# AttributeError: 'dict' object has no attribute 'discipline'

# %%
from box import ConfigBox
fuels = ConfigBox({"discipline":"pos","consistency":"pos2"})
fuels.discipline
# Out:
# 'pos'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get(x:int,y:int)->int:
    return x*y

# %%
get(x=2,y="kallappa")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 get(x=2,y="kallappa")
#
# File c:\Users\kalla\.conda\envs\kidneyCnnenv\lib\site-packages\ensure\main.py:845, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     840     if not isinstance(value, templ):
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
# --> 845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
#     849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get at 0x00000200506220E0> does not match annotation type <class 'int'>

# %%
import gdown

# %%
# my_url="https://drive.google.com/file/d/160uEU3X3NvNFhswkgVAPYwuVa2qeuWDT/view?usp=sharing"
url = "https://drive.google.com/file/d/1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3/view?usp=sharing"

# %%
file_id=url.split('/')[-2]
file_id
# Out:
# '1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3'

# %%
prefix = 'https://drive.google.com/uc?export=download&id='
gdown.download(prefix + file_id, "Kidney-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3
# From (redirected): https://drive.google.com/uc?export=download&id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3&confirm=t&uuid=262c8188-7d16-4a99-83f7-acfa49fa8623
# To: c:\Users\kalla\Desktop\MLOPS\MLOPS_KIDNEY_DISEASE_CNN\research\Kidney-CT-Scan-data.zip
# 100%|██████████| 57.7M/57.7M [00:05<00:00, 11.4MB/s]
# 'Kidney-CT-Scan-data.zip'
